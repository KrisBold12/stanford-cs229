# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(5)
rating  = np.random.uniform(0, 5, (300, 1))
fitness = np.random.uniform(0, 5, (300, 1))
X = np.hstack([rating, fitness]); m = X.shape[0]
X_b = np.hstack([np.ones((m, 1)), X])
valore = 2 + 4*rating + 2*fitness + np.random.randn(m, 1)*2    # vero theta=[2,4,2]
